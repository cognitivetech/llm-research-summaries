# %% [markdown]
# <a href="https://colab.research.google.com/github/cognitivetech/llm-research-summaries/blob/main/bulleted_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 94.6 MB/s eta 0:00:00
# ...

# %%
# !uv pip install -r requirements.txt
# Out:
# Using Python 3.11.12 environment at: /usr
# Resolved 57 packages in 1.53s
#    Building ptable==0.9.2
#    Building ptable==0.9.2
# ⠙ Preparing packages... (0/16)
#    Building ptable==0.9.2
# ⠙ Preparing packages... (0/16)
#    Building ptable==0.9.2
# ⠙ Preparing packages... (0/16)
# bs4        ------------------------------     0 B/1.16 KiB
#    Building ptable==0.9.2
# ⠙ Preparing packages... (0/16)
# bs4        ------------------------------ 1.16 KiB/1.16 KiB
#    Building ptable==0.9.2
# ⠙ Preparing packages... (0/16)
# bs4        ------------------------------ 1.16 KiB/1.16 KiB
# nvidia-cusparse-cu12 ------------------------------     0 B/197.84 MiB
#    Building ptable==0.9.2
# ⠙ Preparing packages... (0/16)
# bs4        ------------------------------ 1.16 KiB/1.16 KiB
# nvidia-cusparse-cu12 ------------------------------ 14.82 KiB/197.84 MiB
#    Building ptable==0.9.2
# ⠙ Preparing packages... (0/16)
# bs4        ------------------------------ 1.16 KiB/1.16 KiB
# ...
